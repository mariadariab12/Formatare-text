# %% [markdown]
# <a href="https://colab.research.google.com/github/mariadariab12/Formatare-text/blob/main/Formatare_text_pentru_plan_documentare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

def format_table_from_excel(file_path: str) -> str:
    df = pd.read_excel(file_path, sheet_name=0)

    df = df.apply(lambda col: col.map(lambda x: str(x).replace('"', '').replace('\n', ' ') if isinstance(x, str) else x))
    df = df.fillna("&nbsp;")

    header = "||" + "||".join(df.columns) + "||\n"
    rows = ""

    for _, row in df.iterrows():
        rows += "|" + "|".join(str(cell) for cell in row) + "|\n"

    return header + rows


xlsx_files = [f for f in os.listdir('/content') if f.endswith('.xlsx')]

if not xlsx_files:
    print("Nu există fișiere .xlsx în /content. Încarcă unul cu files.upload().")
else:
    file_path = os.path.join('/content', xlsx_files[0])

print(format_table_from_excel(file_path))
# Out:
# ||Actiune||Detalii actiune||Efort documentare (h)||Dependente alte resurse||Status||Start date||Due date||
# |Analiza implementare flux RETURN|Sedinta PO/DEV/Operatiuni pentru clarificari|8h|Resurse business/dev|TO DO|10.11|20.11|
# |Analiza flux AS IS|Documentare flux AS IS pe us-uri|6h|Resurse business|TO DO|10.11|19.11|
# |Analiza TO BE a fluxului de return|Creare API pentru transmiterea solicitarii return de catre fintech|8h|&nbsp;|TO DO|10.11|11.11|
# |&nbsp;|Definirea campurilor transmise in JSON prin API|3h|&nbsp;|TO DO|12.11|12.11|
# |&nbsp;|Tratarea mesajelor de eroare + Raspunsuri API (200, 400, 500)|4h|&nbsp;|TO DO|12.11|13.11|
# |&nbsp;|Validari campuri/termen transmitere return (48h)|4h|&nbsp;|&nbsp;|13.11|14.11|
# |&nbsp;|Stabilire motive (coduri) pe care fintech-ul le transmite prin API cand face o solicitare de return|4h|Resurse business|TO DO|14.11|14.11|
# |&nbsp;|API prin  care IBS ne apeleaza cu raspunsul aferent solicitarii de return|5h|&nbsp;|TO DO|17.11|17.11|
# |&nbsp;|Transmitere mesaj push catre fintech (raspuns IBS)|4h|&nbsp;|TO DO|18.11|18.11|
# |&nbsp;|Vizualizare status prin API-ul Get status return|3h|Resurse business|TO DO|18.11|19.11|
# |Aliniere cerinta|Reconciliere cerinta cu departamentul Operatiuni|6h|Resurse business|TO DO|19.11|20.11|
# |Confirmare cerinta operationala|Validare PO/TL IT cerinta|2h|PO/DEV|TO DO|20.11|20.11|
# |Analiza si estimare|Analiza si estimare API return + Validari+ Mesaje eroare|2h|Echipa SCRUM|TO DO|21.11|21.11|
# |Analiza si estimare|Analiza si estimare API transmitere push catre fintech cu raspunsul aferent solicitarii|2h|Echipa SCRUM|TO DO|24.11|24.11|
# |Forma finala US-uri epic|Rafinare finala US-uri epic + Buffer pentru situatii neprevazute|8h|&nbsp;|TO DO|20.11|26.11|
# |&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|
# |&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|
# |&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|&nbsp;|
# |&nbsp;|Total|65h|&nbsp;|&nbsp;|&nbsp;|&nbsp;|
